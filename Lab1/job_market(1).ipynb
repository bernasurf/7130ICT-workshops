# %%
import pandas as pd
import numpy as numpy

# %%
# Load the data using Pandas
df = pd.read_csv('job-market(1).csv')

#remove null rows
df = df.dropna(how='all')

print("The Dataset consists of: ", len(df) , " rows and ", df.shape[1], " columns")



#TODO: Visualize the top 10 first Rows
df.head(10)
# Out:
# The Dataset consists of:  10099  rows and  13  columns
#            Id                                              Title  \
# 0  37404348.0                           Casual Stock Replenisher
# 1  37404337.0                           Casual Stock Replenisher
# 2  37404356.0  RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
# 3  37404330.0                              Team member - Belrose
# 4  37404308.0  Business Banking Contact Centre Specialist, Ni...
# 5  37404307.0  Business Banking Contact Centre Specialist, Ni...
# 6  37404355.0               Casual Café All-rounder in Semaphore
# 7  37404350.0           Casual Café All-rounder in Woolloongabba
# 8  37404301.0                                       Telemarketer
# 9  37404286.0                       Casual Dish Hand in Brighton
#
#                                           Company                      Date  \
# 0                                     Aldi Stores  2018-10-07T00:00:00.000Z
# ...

# %%
df.dtypes
# Out:
# Id                   float64
# Title                 object
# Company               object
# Date                  object
# Location              object
# Area                  object
# Classification        object
# SubClassification     object
# Requirement           object
# FullDescription       object
# LowestSalary         float64
# HighestSalary        float64
# JobType               object
# dtype: object

# %%
#TODO: fix the data type of column Date
df["Date"] = df["Date"].replace(...)
df["Date"] = pd.to_datetime(df["Date"])

df.dtypes
# Out:
# Id                               float64
# Title                             object
# Company                           object
# Date                 datetime64[ns, UTC]
# Location                          object
# Area                              object
# Classification                    object
# SubClassification                 object
# Requirement                       object
# FullDescription                   object
# LowestSalary                     float64
# HighestSalary                    float64
# JobType                           object
# dtype: object

# %%
#check and sum null values
df.isnull().sum()
# Out:
# Id                      0
# Title                   0
# Company               616
# Date                    0
# Location                0
# Area                 3707
# Classification          0
# SubClassification       0
# Requirement             0
# FullDescription       256
# LowestSalary            0
# HighestSalary           0
# JobType               247
# dtype: int64

# %%
# Calculate the average salary as a new column
df = df.assign(AverageSalary = df[['LowestSalary','HighestSalary']].mean(axis=1)) 

#df[df['LowestSalary']>0]
df

#should populate the rows with 0 as lowest salary with the same value as Highest Salary to avoid having the averageSalary as the avg between 0 and the highest salary.
# Out:
#                Id                                              Title  \
# 0      37404348.0                           Casual Stock Replenisher
# 1      37404337.0                           Casual Stock Replenisher
# 2      37404356.0  RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
# 3      37404330.0                              Team member - Belrose
# 4      37404308.0  Business Banking Contact Centre Specialist, Ni...
# ...           ...                                                ...
# 10094  37388912.0                                Executive Assistant
# 10095  37388903.0                   Payroll Officer - Neller Preceda
# 10096  37388901.0                       Receptionist / Administrator
# 10097  37388898.0          INTERNATIONAL WHOLESALE TRAVEL CONSULTANT
# 10098  37388893.0                    Customer Service Representative
#
#                                               Company  \
# 0                                         Aldi Stores
# ...

# %%
df.head(10)
# Out:
#            Id                                              Title  \
# 0  37404348.0                           Casual Stock Replenisher
# 1  37404337.0                           Casual Stock Replenisher
# 2  37404356.0  RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
# 3  37404330.0                              Team member - Belrose
# 4  37404308.0  Business Banking Contact Centre Specialist, Ni...
# 5  37404307.0  Business Banking Contact Centre Specialist, Ni...
# 6  37404355.0               Casual Café All-rounder in Semaphore
# 7  37404350.0           Casual Café All-rounder in Woolloongabba
# 8  37404301.0                                       Telemarketer
# 9  37404286.0                       Casual Dish Hand in Brighton
#
#                                           Company                      Date  \
# 0                                     Aldi Stores  2018-10-07T00:00:00.000Z
# 1                                     Aldi Stores  2018-10-07T00:00:00.000Z
# ...
